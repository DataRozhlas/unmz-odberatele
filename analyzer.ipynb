# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('scratch/matched_v1.tsv', sep='\t')

# %%
match = data[data.differing == 0]

# %%
verejne = pd.read_excel('scratch/statni_obecni_firmy.xlsx')

# %%
ica = []
for ico in verejne.iterrows():
    ica.append(ico[1]['ic'])

# %%
def icor(ico):
    if ico in ica:
        return 'verejna'
    else:
        return np.nan

# %%
match['status'] = match.ico.apply(lambda x: icor(x))
# Out:
# C:\Anaconda3\lib\site-packages\IPython\kernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
agregace.sort('cena', ascending=False)
# Out:
#                              subjekt      cena  status        ic
# 0                      fyzická osoba  11565224     NaN         0
# 1                          ČEZ, a.s.   1097000     NaN  45274649
# 2             Český plynárenský svaz    970250     NaN    409928
# 3                  NORMSERVIS s.r.o.    950276     NaN  26249324
# 4              ČEZ Distribuce, a. s.    730000     NaN  24729035
# 5          ŠKODA PRAHA Invest s.r.o.    582500     NaN  27257517
# 6                       Skanska a.s.    357949     NaN  26271303
# 7          ŠKODA TRANSPORTATION a.s.    344000     NaN  62623753
# 8                      ŠKODA JS a.s.    339000     NaN  25235753
# 9        Dálniční stavby Praha, a.s.    338000     NaN  40614948
# 10                    Metrostav a.s.    325000     NaN     14915
# 11         DOOSAN ŠKODA POWER s.r.o.    296000     NaN  49193864
# 12      ČR-Státní úřad inspekce prác    280000     NaN  75046962
# ...

# %%
agregace = pd.read_csv('data/unikaty.csv')

# %%
agregace['status'] = np.nan

# %%
statusy = {}
for row in match.iterrows():
    statusy[row[1]['original_name']] = {'ico': row[1]['ico'], 'status': row[1]['status']}

# %%
agg = agregace.merge(match, left_on='subjekt', right_on='original_name', how='left')

# %%
agg
# Out:
#                              subjekt      cena  status_x        ic  \
# 0                      fyzická osoba  11565224       NaN         0
# 1                          ČEZ, a.s.   1097000       NaN  45274649
# 2             Český plynárenský svaz    970250       NaN    409928
# 3                  NORMSERVIS s.r.o.    950276       NaN  26249324
# 4              ČEZ Distribuce, a. s.    730000       NaN  24729035
# 5          ŠKODA PRAHA Invest s.r.o.    582500       NaN  27257517
# 6                       Skanska a.s.    357949       NaN  26271303
# 7          ŠKODA TRANSPORTATION a.s.    344000       NaN  62623753
# 8                      ŠKODA JS a.s.    339000       NaN  25235753
# 9        Dálniční stavby Praha, a.s.    338000       NaN  40614948
# 10                    Metrostav a.s.    325000       NaN     14915
# 11         DOOSAN ŠKODA POWER s.r.o.    296000       NaN  49193864
# 12      ČR-Státní úřad inspekce prác    280000       NaN  75046962
# ...

# %%
agg.sort('cena', ascending=False).to_excel('data/odberatele_status.xlsx', index=False)
