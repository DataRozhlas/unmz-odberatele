# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
data = pd.read_excel('data/odberatele_status.xlsx')

# %%
data.status_y.value_counts()
# Out:
# s          383
# v          375
# verejna    145
# vz          72
# dtype: int64

# %%
#celkem
data.cena.sum()
# Out:
# 60604682

# %%
#stat
data[data.status_y == 'v'].cena.sum()
# Out:
# 5008104

# %%
#statni firmy
data[data.status_y == 'verejna'].cena.sum()
# Out:
# 4017243

# %%
#skoly
data[data.status_y == 'vz'].cena.sum()
# Out:
# 958274

# %%
data[data.status_y == 'verejna'].sort('cena', ascending=False)
# Out:
#                              subjekt     cena  status_x        ic  \
# 1                          ČEZ, a.s.  1097000       NaN  45274649
# 4              ČEZ Distribuce, a. s.   730000       NaN  24729035
# 14       DOPRAVNÍ PODNIK HL.M.PRAHY,   256000       NaN      5886
# 16                        ČEPS, a.s.   250000       NaN  25702556
# 23        Technický a zkušební ústav   196180       NaN     15679
# 44           Český Aeroholding, a.s.    92000       NaN       NaN
# 52      Strojírenský zkušební ústav,    84243       NaN       NaN
# 55                      ČEPRO, a. s.    78000       NaN       NaN
# 61    ČEZ Distribuční služby, s.r.o.    73125       NaN       NaN
# 62                 České dráhy, a.s.    73000       NaN       NaN
# 68                     PRODECO, a.s.    67750       NaN       NaN
# 76             Severočeské doly a.s.    61000       NaN       NaN
# 82              DIAMO, státní podnik    56500       NaN       NaN
# ...
